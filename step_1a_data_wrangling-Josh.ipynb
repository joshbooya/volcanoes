# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from functools import partial
from decimal import Decimal

import warnings
warnings.filterwarnings('ignore')

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func, and_, or_

import seaborn as sns
import matplotlib.dates as mdates
import matplotlib.ticker as ticker


from flask import Flask, jsonify

import time
from splinter import Browser
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import re

# %%
# df0_sig = pd.read_csv("raw_data/Significant_Volcanic_Eruption.csv")
# df0_sig.info()
# df0_sig.head()

# %%
# df1_sig = df0_sig[[
#     'Year', 'Month'
#     , 'Day', 'TSU'
#     , 'EQ', 'Name'
#     , 'Location', 'Country'
#     , 'Latitude', 'Longitude'
#     , 'Elevation', 'Type'
#     , 'Status', 'Time'
#     , 'VEI', 'Agent'
#     ]].fillna(0)

# df1_sig.info()
# df1_sig.head()

# %% [markdown]
# ## Data Set 1: Volcanos with Confirmed Erruptions -- Smithsonian Institute Global Volcanism Program
# http://volcano.si.edu/database/search_eruption_results.cfm
# - confirmed erruptions database search results

# %%
df0_erupt_gvp = pd.read_excel("raw_data/GVP_Eruption_Results.xlsx", sheetname='Eruption List')
df0_erupt_gvp.info()
df0_erupt_gvp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9841 entries, 0 to 9840
# Data columns (total 24 columns):
# Global Volcanism Program - Volcanoes of the World 4.6.6    9841 non-null object
# Unnamed: 1                                                 9841 non-null object
# Unnamed: 2                                                 9841 non-null object
# Unnamed: 3                                                 9841 non-null object
# Downloaded on 09 Mar 2018 at 07:48 PM                      4390 non-null object
# Unnamed: 5                                                 7564 non-null object
# Unnamed: 6                                                 1102 non-null object
# Unnamed: 7                                                 1569 non-null object
# Unnamed: 8                                                 9840 non-null object
# Unnamed: 9                                                 2049 non-null object
# Unnamed: 10                                                9660 non-null object
# Unnamed: 11                                                388 non-null object
# Unnamed: 12                                                9659 non-null object
# Unnamed: 13                                                709 non-null object
# Unnamed: 14                                                9794 non-null object
# Unnamed: 15                                                90 non-null object
# Unnamed: 16                                                3943 non-null object
# Unnamed: 17                                                7 non-null object
# Unnamed: 18                                                3941 non-null object
# Unnamed: 19                                                700 non-null object
# Unnamed: 20                                                3940 non-null object
# Unnamed: 21                                                627 non-null object
# Unnamed: 22                                                9841 non-null object
# Unnamed: 23                                                9841 non-null object
# dtypes: object(24)
# memory usage: 1.8+ MB
#   Global Volcanism Program - Volcanoes of the World 4.6.6    Unnamed: 1  \
# 0                                     Volcano Number       Volcano Name
# 1                                             343100         San Miguel
# 2                                             273030              Mayon
# 3                                             251002            Kadovar
# 4                                             272020            Kanlaon
#
#         Unnamed: 2          Unnamed: 3 Downloaded on 09 Mar 2018 at 07:48 PM  \
# 0  Eruption Number   Eruption Category                      Area of Activity
# 1            22251  Confirmed Eruption                                   NaN
# 2            22250  Confirmed Eruption                                   NaN
# 3            22246  Confirmed Eruption                                   NaN
# 4            22249  Confirmed Eruption                                   NaN
#
#   Unnamed: 5    Unnamed: 6           Unnamed: 7  Unnamed: 8  \
# 0        VEI  VEI Modifier  Start Year Modifier  Start Year
# 1        NaN           NaN                  NaN        2018
# 2        NaN           NaN                  NaN        2018
# 3        NaN           NaN                  NaN        2018
# 4        NaN           NaN                  NaN        2017
#
#                Unnamed: 9     ...                   Unnamed: 14  \
# 0  Start Year Uncertainty     ...      Evidence Method (dating)
# 1                     NaN     ...       Historical Observations
# 2                     NaN     ...       Historical Observations
# 3                     NaN     ...       Historical Observations
# 4                     NaN     ...       Historical Observations
#
#          Unnamed: 15 Unnamed: 16           Unnamed: 17 Unnamed: 18  \
# 0  End Year Modifier    End Year  End Year Uncertainty   End Month
# 1                NaN        2018                   NaN           1
# 2                  >        2018                   NaN           1
# 3                  >        2018                   NaN           1
# 4                NaN        2017                   NaN          12
#
#         Unnamed: 19 Unnamed: 20          Unnamed: 21 Unnamed: 22 Unnamed: 23
# 0  End Day Modifier     End Day  End Day Uncertainty    Latitude   Longitude
# 1               NaN          15                  NaN      13.434     -88.269
# 2               NaN          19                  NaN      13.257     123.685
# 3               NaN          19                  NaN      -3.608     144.588
# 4               NaN           9                  NaN      10.412     123.132
#
# [5 rows x 24 columns]

# %%
df1_erupt_gvp = df0_erupt_gvp.rename(
    columns = df0_erupt_gvp.iloc[0]).drop(
    df0_erupt_gvp.index[0]).reset_index(drop=True)

df1_erupt_gvp.info()
df1_erupt_gvp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 24 columns):
# Volcano Number              9840 non-null object
# Volcano Name                9840 non-null object
# Eruption Number             9840 non-null object
# Eruption Category           9840 non-null object
# Area of Activity            4389 non-null object
# VEI                         7563 non-null object
# VEI Modifier                1101 non-null object
# Start Year Modifier         1568 non-null object
# Start Year                  9839 non-null object
# Start Year Uncertainty      2048 non-null object
# Start Month                 9659 non-null object
# Start Day Modifier          387 non-null object
# Start Day                   9658 non-null object
# Start Day Uncertainty       708 non-null object
# Evidence Method (dating)    9793 non-null object
# End Year Modifier           89 non-null object
# End Year                    3942 non-null object
# End Year Uncertainty        6 non-null object
# End Month                   3940 non-null object
# End Day Modifier            699 non-null object
# End Day                     3939 non-null object
# End Day Uncertainty         626 non-null object
# Latitude                    9840 non-null object
# Longitude                   9840 non-null object
# dtypes: object(24)
# memory usage: 1.8+ MB
#   Volcano Number Volcano Name Eruption Number   Eruption Category  \
# 0         343100   San Miguel           22251  Confirmed Eruption
# 1         273030        Mayon           22250  Confirmed Eruption
# 2         251002      Kadovar           22246  Confirmed Eruption
# 3         272020      Kanlaon           22249  Confirmed Eruption
# 4         264020        Agung           22241  Confirmed Eruption
#
#   Area of Activity  VEI VEI Modifier Start Year Modifier Start Year  \
# 0              NaN  NaN          NaN                 NaN       2018
# 1              NaN  NaN          NaN                 NaN       2018
# 2              NaN  NaN          NaN                 NaN       2018
# 3              NaN  NaN          NaN                 NaN       2017
# 4              NaN  NaN          NaN                 NaN       2017
#
#   Start Year Uncertainty    ...    Evidence Method (dating) End Year Modifier  \
# 0                    NaN    ...     Historical Observations               NaN
# 1                    NaN    ...     Historical Observations                 >
# 2                    NaN    ...     Historical Observations                 >
# 3                    NaN    ...     Historical Observations               NaN
# 4                    NaN    ...     Historical Observations                 >
#
#   End Year End Year Uncertainty End Month End Day Modifier End Day  \
# 0     2018                  NaN         1              NaN      15
# 1     2018                  NaN         1              NaN      19
# 2     2018                  NaN         1              NaN      19
# 3     2017                  NaN        12              NaN       9
# 4     2018                  NaN         1              NaN      15
#
#   End Day Uncertainty Latitude Longitude
# 0                 NaN   13.434   -88.269
# 1                 NaN   13.257   123.685
# 2                 NaN   -3.608   144.588
# 3                 NaN   10.412   123.132
# 4                 NaN   -8.343   115.508
#
# [5 rows x 24 columns]

# %%
df1_erupt_gvp.Latitude[0]
type(df1_erupt_gvp.Latitude[0])
# Out:
# float

# %% [markdown]
# #### Descriptions of VEI found in the link below
# https://www.ngdc.noaa.gov/nndc/DescribeField.jsp?dataset=102557&s=77&field_name=HAZ.VOLCANO_EVENT.VEI
#  - filled NaN with 0

# %%
df2_erupt_gvp = df1_erupt_gvp[[
    'Volcano Number'
    ,'Volcano Name'
   ,'VEI','Start Year'
   ,'Start Month','Start Day'
   ,'End Year','End Month','End Day'
   ,'Latitude','Longitude'
]].apply(
    partial(
        pd.to_numeric
        , errors='ignore'
    ))
df2_erupt_gvp.info()
df2_erupt_gvp
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Data columns (total 11 columns):
# Volcano Number    9840 non-null int64
# Volcano Name      9840 non-null object
# VEI               7563 non-null float64
# Start Year        9839 non-null float64
# Start Month       9659 non-null float64
# Start Day         9658 non-null float64
# End Year          3942 non-null float64
# End Month         3940 non-null float64
# End Day           3939 non-null float64
# Latitude          9840 non-null float64
# Longitude         9840 non-null float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 845.7+ KB
#       Volcano Number            Volcano Name  VEI  Start Year  Start Month  \
# 0             343100              San Miguel  NaN      2018.0          1.0
# 1             273030                   Mayon  NaN      2018.0          1.0
# 2             251002                 Kadovar  NaN      2018.0          1.0
# 3             272020                 Kanlaon  NaN      2017.0         12.0
# 4             264020                   Agung  NaN      2017.0         11.0
# 5             261230                   Dempo  NaN      2017.0         11.0
# 6             256010                Tinakula  3.0      2017.0         10.0
# 7             282090           Kirishimayama  NaN      2017.0         10.0
# 8             257030                   Ambae  3.0      2017.0          9.0
# 9             353010              Fernandina  NaN      2017.0          9.0
# 10            344020           San Cristobal  NaN      2017.0          8.0
# 11            352090                  Sangay  NaN      2017.0          7.0
# 12            264050            Sangeang Api  NaN      2017.0          7.0
# 13            233020  Fournaise, Piton de la  NaN      2017.0          7.0
# 14            252120                  Ulawun  NaN      2017.0          6.0
# 15            273010                 Bulusan  NaN      2017.0          6.0
# 16            261140                  Marapi  NaN      2017.0          6.0
# 17            300130                Karymsky  NaN      2017.0          6.0
# 18            357090                 Copahue  NaN      2017.0          6.0
# 19            345020      Rincon de la Vieja  NaN      2017.0          5.0
# 20            263200  Dieng Volcanic Complex  NaN      2017.0          4.0
# 21            284096            Nishinoshima  2.0      2017.0          4.0
# 22            345040                    Poas  NaN      2017.0          4.0
# 23            282080                    Aira  1.0      2017.0          3.0
# 24            300010                Kambalny  3.0      2017.0          3.0
# 25            262000                Krakatau  NaN      2017.0          2.0
# 26            311240               Cleveland  NaN      2017.0          2.0
# 27            233020  Fournaise, Piton de la  NaN      2017.0          1.0
# 28            243030                 Unnamed  NaN      2017.0          1.0
# 29            260010           Barren Island  2.0      2017.0          1.0
# ...              ...                     ...  ...         ...          ...
# 9810          371040       Brennisteinsfjoll  0.0     -9000.0          0.0
# 23         25.0    2018.0        1.0     19.0    31.593    130.657
# 24         24.0    2017.0        4.0     10.0    51.306    156.875
# 25         19.0    2017.0        2.0     19.0    -6.102    105.423
# 26          3.0    2018.0        1.0      5.0    52.825   -169.944
# 27         31.0    2017.0        2.0     27.0   -21.244     55.708
# 28         23.0    2017.0        1.0     31.0   -20.852   -175.550
# 29         15.0    2017.0        5.0     16.0    12.278     93.858
# ...         ...       ...        ...      ...       ...        ...
# 9810        0.0       NaN        NaN      NaN    63.933    -21.783
# 9811        NaN       NaN        NaN      NaN    43.420   -113.500
# 9812        0.0       NaN        NaN      NaN    33.086    131.249
# 9813        0.0       NaN        NaN      NaN    43.722   -121.229
# 9814        0.0       NaN        NaN      NaN   -38.820    176.000
# 9815        0.0       NaN        NaN      NaN   -38.820    176.000
# 9816        0.0       NaN        NaN      NaN   -39.637    -71.502
# 9817        0.0       NaN        NaN      NaN     8.808    -82.543
# 9818        0.0       NaN        NaN      NaN    60.485   -152.742
# 9819        0.0       NaN        NaN      NaN   -39.157    175.632
# 9820        NaN       NaN        NaN      NaN    50.324    155.461
# 9821        0.0       NaN        NaN      NaN    15.132    -92.109
# 9822        0.0       NaN        NaN      NaN   -39.157    175.632
# 9823        NaN       NaN        NaN      NaN    34.250   -108.830
# 9824        0.0       NaN        NaN      NaN   -38.820    176.000
# 9825        0.0       NaN        NaN      NaN    40.510    140.880
# 9826        0.0       NaN        NaN      NaN    54.761    157.407
# 9827        0.0       NaN        NaN      NaN    65.833    -17.166
# 9828        0.0       NaN        NaN      NaN    30.443    130.218
# 9829        0.0       NaN        NaN      NaN    36.765    139.491
# 9830        0.0       NaN        NaN      NaN   -39.157    175.632
# 9831        0.0       NaN        NaN      NaN   -39.280    175.570
# 9832        NaN       NaN        NaN      NaN    34.250   -108.830
# 9833        0.0       NaN        NaN      NaN   -39.280    175.570
# 9834        0.0       NaN        NaN      NaN   -39.157    175.632
# 9835        NaN       NaN        NaN      NaN    34.250   -108.830
# 9836        0.0       NaN        NaN      NaN    38.654     42.229
# 9837        NaN       NaN        NaN      NaN    43.420   -113.500
# 9838        NaN       NaN        NaN      NaN    -4.889     31.933
# 9839        NaN       NaN        NaN      NaN    -8.420    116.470
#
# [9840 rows x 11 columns]

# %%
df2_erupt_gvp.Latitude[0]
type(df2_erupt_gvp.Latitude[2])
# Out:
# numpy.float64

# %% [markdown]
# ## Data Set 2: Volcanos With Metadata -- Smithsonian Institute
# http://volcano.si.edu/database/search_volcano_results.cfm
# - All volcanos

# %%
df0_vol_gvp = pd.read_excel("raw_data/GVP_Volcano_List_ALL.xlsx", sheetname='Volcano List')
df0_vol_gvp.info()
# df0_vol_meta.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12826 entries, 0 to 12825
# Data columns (total 26 columns):
# Global Volcanism Program - Volcanoes of the World 4.6.6    12826 non-null object
# Unnamed: 1                                                 12826 non-null object
# Unnamed: 2                                                 12825 non-null object
# Downloaded on 09 Mar 2018 at 03:04 PM                      1445 non-null object
# Unnamed: 4                                                 1445 non-null object
# Unnamed: 5                                                 1445 non-null object
# Unnamed: 6                                                 1445 non-null object
# Unnamed: 7                                                 1445 non-null object
# Unnamed: 8                                                 1445 non-null object
# Unnamed: 9                                                 1445 non-null object
# Unnamed: 10                                                1439 non-null object
# Unnamed: 11                                                1445 non-null object
# Unnamed: 12                                                1445 non-null object
# Unnamed: 13                                                1445 non-null object
# Unnamed: 14                                                1445 non-null object
# Unnamed: 15                                                1445 non-null object
# Unnamed: 16                                                1445 non-null object
# Unnamed: 17                                                1445 non-null object
# Unnamed: 18                                                1445 non-null object
# Unnamed: 19                                                1445 non-null object
# Unnamed: 20                                                1445 non-null object
# Unnamed: 21                                                1445 non-null object
# Unnamed: 22                                                1445 non-null object
# Unnamed: 23                                                1445 non-null object
# Unnamed: 24                                                1445 non-null object
# Unnamed: 25                                                1445 non-null object
# dtypes: object(26)
# memory usage: 2.5+ MB

# %%
df1_vol_gvp = df0_vol_gvp.rename(
    columns=df0_vol_gvp.iloc[0]).drop(
    df0_vol_gvp.index[0]).reset_index(drop=True)

df1_vol_gvp.info()
df1_vol_gvp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12825 entries, 0 to 12824
# Data columns (total 26 columns):
# Volcano Number              12825 non-null object
# Volcano Name                12825 non-null object
# Primary Volcano Type        12824 non-null object
# Last Eruption Year          1444 non-null object
# Country                     1444 non-null object
# Region                      1444 non-null object
# Subregion                   1444 non-null object
# Latitude                    1444 non-null object
# Longitude                   1444 non-null object
# Elevation                   1444 non-null object
# Tectonic Settings           1438 non-null object
# Evidence Category           1444 non-null object
# Major Rock 1                1444 non-null object
# Major Rock 2                1444 non-null object
# Major Rock 3                1444 non-null object
# Major Rock 4                1444 non-null object
# Major Rock 5                1444 non-null object
# Minor Rock 1                1444 non-null object
# Minor Rock 2                1444 non-null object
# Minor Rock 3                1444 non-null object
# Minor Rock 4                1444 non-null object
# Minor Rock 5                1444 non-null object
# Population within 5 km      1444 non-null object
# Population within 10 km     1444 non-null object
# Population within 30 km     1444 non-null object
# Population within 100 km    1444 non-null object
# dtypes: object(26)
# memory usage: 2.5+ MB
#   Volcano Number           Volcano Name              Primary Volcano Type  \
# 0         231160      'Ares, Djebel el-           Synonym of Urais, Jabal
# 1         231020  'Awayridh, Harrat el-        Synonym of Uwayrid, Harrat
# 2         231020  'Uweirizh, Harrat el-        Synonym of Uwayrid, Harrat
# 3         343050     14 de Marzo, Cerro  Pyroclastic cone of San Salvador
# 4         244010                  A'ofa     Shield volcano of Ofu-Olosega
#
#   Last Eruption Year Country Region Subregion Latitude Longitude Elevation  \
# 0                NaN     NaN    NaN       NaN      NaN       NaN       NaN
# 1                NaN     NaN    NaN       NaN      NaN       NaN       NaN
# 2                NaN     NaN    NaN       NaN      NaN       NaN       NaN
# 3                NaN     NaN    NaN       NaN      NaN       NaN       NaN
# 4                NaN     NaN    NaN       NaN      NaN       NaN       NaN
#
#             ...            Major Rock 5 Minor Rock 1 Minor Rock 2  \
# 0           ...                     NaN          NaN          NaN
# 1           ...                     NaN          NaN          NaN
# 2           ...                     NaN          NaN          NaN
# 3           ...                     NaN          NaN          NaN
# 4           ...                     NaN          NaN          NaN
#
#   Minor Rock 3 Minor Rock 4 Minor Rock 5 Population within 5 km  \
# 0          NaN          NaN          NaN                    NaN
# 1          NaN          NaN          NaN                    NaN
# 2          NaN          NaN          NaN                    NaN
# 3          NaN          NaN          NaN                    NaN
# 4          NaN          NaN          NaN                    NaN
#
#   Population within 10 km Population within 30 km Population within 100 km
# 0                     NaN                     NaN                      NaN
# 1                     NaN                     NaN                      NaN
# 2                     NaN                     NaN                      NaN
# 3                     NaN                     NaN                      NaN
# 4                     NaN                     NaN                      NaN
#
# [5 rows x 26 columns]

# %%
df2_vol_gvp = df1_vol_gvp[[
    'Volcano Number'
    ,'Volcano Name'
    ,'Country','Region'
    ,'Latitude'
    ,'Longitude','Elevation'
    ,'Evidence Category'
    ,'Primary Volcano Type'
]].dropna(subset = ['Country']).reset_index(drop=True).apply(
    partial(
        pd.to_numeric
        , errors='ignore'))

df2_vol_gvp.info()
df2_vol_gvp
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1444 entries, 0 to 1443
# Data columns (total 9 columns):
# Volcano Number          1444 non-null int64
# Volcano Name            1444 non-null object
# Country                 1444 non-null object
# Region                  1444 non-null object
# Latitude                1444 non-null float64
# Longitude               1444 non-null float64
# Elevation               1444 non-null int64
# Evidence Category       1444 non-null object
# Primary Volcano Type    1443 non-null object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 101.6+ KB
#       Volcano Number              Volcano Name            Country  \
# 0             283001                       Abu              Japan
# 1             355096                Acamarachi              Chile
# 2             342080                Acatenango          Guatemala
# 3             213004           Acigol-Nevsehir             Turkey
# 4             321040                     Adams      United States
# 5             333050            Adams Seamount  Undersea Features
# 6             283170               Adatarayama              Japan
# 7             221170                      Adwa           Ethiopia
# 8             221110                    Afdera           Ethiopia
# 9             284160                   Agrigan      United States
# 10            342100                      Agua          Guatemala
# 11            382090               Agua de Pau           Portugal
# 12            358062                  Aguilera              Chile
# 13            264020                     Agung          Indonesia
# 14            284141                      Ahyi      United States
# 15            282080                      Aira              Japan
# 16            300125             Akademia Nauk             Russia
# 17            283130                  Akagisan              Japan
# 18            285070                      Akan              Japan
# 19            283069              Akandanayama              Japan
# 20            300320                   Akhtang             Russia
# 21            283230          Akita-Komagatake              Japan
# 22            283260            Akita-Yakeyama              Japan
# 23            282022               Akusekijima              Japan
# 24            311320                    Akutan      United States
# 25            290390                     Alaid             Russia
# 26            284180                  Alamagan      United States
# 27            221112                    Alayta           Ethiopia
# 28            353040                    Alcedo            Ecuador
# 29            221090                  Ale Bagu           Ethiopia
# ...              ...                       ...                ...
# 1414          358049                  Yanteles              Chile
# 1415          231080                Yar, Jabal       Saudi Arabia
# 1416          257100                     Yasur            Vanuatu
# 1417          358022                      Yate              Chile
# 1418          300021                  Yavinsky             Russia
# 1419          325010               Yellowstone      United States
# 1420          343150               Yojoa, Lake           Honduras
# 1421          282021              Yokoate-jima              Japan
# 1422          283031                  Yokodake              Japan
# 1423          282081     Yonemaru-Sumiyoshiike              Japan
# 1424          285032                  Yoteizan              Japan
# 1425          390011              Young Island         Antarctica
# 1426          354050                  Yucamane               Peru
# 1427          282130              Yufu-Tsurumi              Japan
# 1428          311210                   Yunaska      United States
# 1429          343140       Zacate Grande, Isla           Honduras
# 1430          283190                    Zaozan              Japan
# 1431          300480                  Zaozerny             Russia
# 1440      Eruption Dated              Caldera
# 1441   Eruption Observed               Shield
# 1442   Evidence Credible               Shield
# 1443      Eruption Dated       Volcanic field
#
# [1444 rows x 9 columns]

# %%
type(df2_vol_gvp.Latitude[2])
# Out:
# numpy.float64

# %% [markdown]
# ## Merge Data Sets 1 & 2

# %%
df_erupt_merge0 = pd.merge(
    df2_erupt_gvp, df2_vol_gvp, 
    how='left', 
    on=['Volcano Number',
        'Volcano Name',
        'Latitude',
        'Longitude'], 
    left_on=None, right_on=None,
    left_index=False, right_index=False, 
    sort=True, suffixes=('_x', '_y'), 
    copy=True, indicator=False)

df_erupt_merge0.info()
df_erupt_merge0.head()

#######################################################
#### This merge causese Lat/Long to be a floating point 
#### with more than numbers more than 3 decimals places
#######################################################

df_erupt_merge0.to_csv('data_check/EruptionData0_chk.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9840 entries, 0 to 9839
# Data columns (total 16 columns):
# Volcano Number          9840 non-null int64
# Volcano Name            9840 non-null object
# VEI                     7563 non-null float64
# Start Year              9839 non-null float64
# Start Month             9659 non-null float64
# Start Day               9658 non-null float64
# End Year                3942 non-null float64
# End Month               3940 non-null float64
# End Day                 3939 non-null float64
# Latitude                9840 non-null float64
# Longitude               9840 non-null float64
# Country                 9840 non-null object
# Region                  9840 non-null object
# Elevation               9840 non-null int64
# Evidence Category       9840 non-null object
# Primary Volcano Type    9763 non-null object
# dtypes: float64(9), int64(2), object(5)
# memory usage: 1.3+ MB

# %%
for index, row in df_erupt_merge0.iterrows():
    df_erupt_merge0['Latitude'][index] = round(row['Latitude'],3)
    print('.', end='')
# Out:
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
type(df_erupt_merge0['Latitude'][0])
df_erupt_merge0['Latitude'][0]
# Out:
# 50.170000000000002

# %% [markdown]
# ## Comprehensive list of Volcanos -- NOAA
# https://www.ngdc.noaa.gov/nndc/struts/results?type_0=Like&query_0=&op_8=eq&v_8=&type_10=EXACT&query_10=None+Selected&le_2=&ge_3=&le_3=&ge_2=&op_5=eq&v_5=&op_6=eq&v_6=&op_7=eq&v_7=&t=102557&s=5&d=5

# %%
url = 'https://www.ngdc.noaa.gov/nndc/struts/results?type_0=Like&query_0=&op_8=eq&v_8=&type_10=EXACT&query_10=None+Selected&le_2=&ge_3=&le_3=&ge_2=&op_5=eq&v_5=&op_6=eq&v_6=&op_7=eq&v_7=&t=102557&s=5&d=5'
noaa_tablesv0 = pd.read_html(url)[1]

noaa_tablev1 = noaa_tablesv0.rename(
    columns = noaa_tablesv0.iloc[1]).drop(
    noaa_tablesv0.index[[0,1]]).reset_index(drop=True)

# %%
noaa_vol_table = noaa_tablev1[[
    'Volcano Name', 
    'Country', 'Region', 
    'Latitude', 'Longitude', 
    'Elev', 'Type', 'Status']].apply(
    partial(
        pd.to_numeric
        , errors='ignore'
    )).rename(columns = {
    'Elev':'Elevation',
    'Type':'Primary Volcano Type'}).drop_duplicates([
    'Volcano Name','Country','Region'])

noaa_vol_table.info()
noaa_vol_table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1497 entries, 0 to 1570
# Data columns (total 8 columns):
# Volcano Name            1497 non-null object
# Country                 1497 non-null object
# Region                  1497 non-null object
# Latitude                1497 non-null float64
# Longitude               1497 non-null float64
# Elevation               1489 non-null float64
# Primary Volcano Type    1497 non-null object
# Status                  1497 non-null object
# dtypes: float64(3), object(5)
# memory usage: 105.3+ KB
#              Volcano Name           Country                Region  Latitude  \
# 0                     Abu             Japan          Honshu-Japan    34.500
# 1              Acamarachi             Chile               Chile-N   -23.300
# 2              Acatenango         Guatemala             Guatemala    14.501
# 3         Acigol-Nevsehir            Turkey                Turkey    38.570
# 4                   Adams     United States         US-Washington    46.206
# 5                 Adatara             Japan          Honshu-Japan    37.620
# 6                    Adwa          Ethiopia             Africa-NE    10.070
# 7                  Afdera          Ethiopia             Africa-NE    13.080
# 8         Agmagan-Karadag           Armenia               Armenia    40.275
# 9                 Agrigan     United States  Mariana Is-C Pacific    18.770
# 10                   Agua         Guatemala             Guatemala    14.465
# 11            Agua de Pau          Portugal                Azores    37.770
# 12               Aguilera             Chile               Chile-S   -50.170
# 13                  Agung         Indonesia       Lesser Sunda Is    -8.342
# 14                   Ahyi     United States  Mariana Is-C Pacific    20.420
# 15          Akademia Nauk            Russia             Kamchatka    53.980
# 17                  Akagi             Japan          Honshu-Japan    36.530
# 18                   Akan             Japan        Hokkaido-Japan    43.380
# 19                Akhtang            Russia             Kamchatka    55.430
# 20      Akita-Komaga-take             Japan          Honshu-Japan    39.750
# 21        Akita-Yake-yama             Japan          Honshu-Japan    39.970
# 22           Akuseki-jima             Japan             Ryukyu Is    29.450
# 24                 Akutan     United States           Aleutian Is    54.130
# 25                  Alaid            Russia              Kuril Is    50.858
# 26               Alamagan     United States  Mariana Is-C Pacific    17.600
# 27                 Alayta          Ethiopia             Africa-NE    12.880
# 28          Albano, Monte             Italy                 Italy    41.730
# 29         Alcedo, Volcan           Ecuador             Galapagos    -0.430
# 30               Ale Bagu          Ethiopia             Africa-NE    13.520
# 31                   Alid           Eritrea             Africa-NE    14.880
# ...                   ...               ...                   ...       ...
# 1540             Yantarni     United States      Alaska Peninsula    57.020
# 1541             Yanteles             Chile               Chile-S   -43.500
# 1542      Yanteles, Cerro             Chile               Chile-S   -43.420
# 1543           Yar, Jabal      Saudi Arabia              Arabia-W    17.050
# 1544                Yasur           Vanuatu    Vanuatu-SW Pacific   -19.520
# 1545                 Yate             Chile               Chile-S   -41.755
# 1546                Yelia  Papua New Guinea            New Guinea    -7.050
# 1547          Yellowstone     United States            US-Wyoming    44.430
# 1548               Yersey         Indonesia       Lesser Sunda Is    -7.530
# 1549          Yojoa, Lake          Honduras              Honduras    14.980
# 1550                Yomba  Papua New Guinea      New Guinea-NE of    -4.920
# 1551                Yotei             Japan        Hokkaido-Japan    42.830
# 1552         Young Island        Antarctica            Antarctica   -66.420
# 1553             Yucamane              Peru                  Peru   -17.180
# 1554         Yumia, Cerro           Bolivia               Bolivia   -21.500
# 1555              Yunaska     United States           Aleutian Is    52.630
# 1556  Zacate Grande, Isla          Honduras              Honduras    13.330
# 1557                  Zao             Japan          Honshu-Japan    38.150
# 1558             Zaozerny            Russia             Kamchatka    56.880
# 1556    -87.630      600.0        Stratovolcano          Holocene
# 1557    140.450     1841.0      Complex volcano        Historical
# 1558    159.950     1349.0       Shield volcano          Holocene
# 1559    -85.820      629.0       Shield volcano          Holocene
# 1560    158.385     1567.0         Cinder cones       Radiocarbon
# 1562    151.950      624.0              Caldera        Historical
# 1563    -27.570      551.0        Stratovolcano        Historical
# 1564    122.458     -418.0    Submarine volcano        Historical
# 1565    157.323     1953.0        Stratovolcano        Historical
# 1566    159.147     2958.0     Compound volcano        Historical
# 1567    160.603     3081.0        Stratovolcano          Holocene
# 1568     42.180      191.0       Shield volcano        Historical
# 1569     42.750      624.0       Shield volcano          Holocene
# 1570   -108.000     2550.0       Volcanic field      Anthropology
#
# [1497 rows x 8 columns]

# %%
type(noaa_vol_table.Latitude[0])
noaa_vol_table.Latitude[0]
# Out:
# 34.5

# %%
noaa_vol_table.info()
print('')
df_erupt_merge0.info()
noaa_vol_table.to_csv('data_check/noaa_vol_table1_chk.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1497 entries, 0 to 1570
# Data columns (total 8 columns):
# Volcano Name            1497 non-null object
# Country                 1497 non-null object
# Region                  1497 non-null object
# Latitude                1497 non-null float64
# Longitude               1497 non-null float64
# Elevation               1489 non-null float64
# Primary Volcano Type    1497 non-null object
# Status                  1497 non-null object
# dtypes: float64(3), object(5)
# memory usage: 145.3+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9840 entries, 0 to 9839
# Data columns (total 16 columns):
# Volcano Number          9840 non-null int64
# Volcano Name            9840 non-null object
# VEI                     7563 non-null float64
# Start Year              9839 non-null float64
# Start Month             9659 non-null float64
# Start Day               9658 non-null float64
# End Year                3942 non-null float64
# End Month               3940 non-null float64
# End Day                 3939 non-null float64
# Latitude                9840 non-null float64
# Longitude               9840 non-null float64
# Country                 9840 non-null object
# Region                  9840 non-null object
# Elevation               9840 non-null int64
# Evidence Category       9840 non-null object
# Primary Volcano Type    9763 non-null object
# dtypes: float64(9), int64(2), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Merging Data Sets (1/2) + 3

# %%
df_erupt_merge2 = pd.merge(df_erupt_merge0[[
    'Volcano Name','VEI',
    'Start Year','Start Month','Start Day',
    'End Year','End Month','End Day',
    'Country','Region','Latitude',
    'Longitude','Elevation', 
    'Primary Volcano Type']], noaa_vol_table[[
    'Volcano Name','Country','Region',
    'Latitude', 'Longitude',
    'Elevation','Primary Volcano Type',
    'Status']], how='left', on=['Volcano Name','Latitude', 'Longitude'], left_on=None, right_on=None,
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False)

df_erupt_merge2.info()
df_erupt_merge2

# s1 = 'Primary Volcano Type'
# s2 = 'Status'

# x = vol_table[s1].isnull().sum()
# y = vol_table[s2].isnull().sum()

# print(f'There are {x} unknown {s1} values.\n There are {y} unknown {s2} values')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9840 entries, 0 to 9839
# Data columns (total 19 columns):
# Volcano Name              9840 non-null object
# VEI                       7563 non-null float64
# Start Year                9839 non-null float64
# Start Month               9659 non-null float64
# Start Day                 9658 non-null float64
# End Year                  3942 non-null float64
# End Month                 3940 non-null float64
# End Day                   3939 non-null float64
# Country_x                 9840 non-null object
# Region_x                  9840 non-null object
# Latitude                  9840 non-null float64
# Longitude                 9840 non-null float64
# Elevation_x               9840 non-null int64
# Primary Volcano Type_x    9763 non-null object
# Country_y                 2691 non-null object
# Region_y                  2691 non-null object
# Elevation_y               2691 non-null float64
# Primary Volcano Type_y    2691 non-null object
# Status                    2691 non-null object
# dtypes: float64(10), int64(1), object(8)
# memory usage: 1.5+ MB
#                   Volcano Name  VEI  Start Year  Start Month  Start Day  \
# 0                          Abu  NaN     -6850.0          0.0        0.0
# 1                   Acatenango  1.0      1972.0         11.0       12.0
# 2                   Acatenango  2.0      1926.0          8.0        0.0
# 3                   Acatenango  3.0      1924.0         12.0       18.0
# 4                   Acatenango  NaN      1450.0          0.0        0.0
# 5                   Acatenango  NaN        90.0          0.0        0.0
# 6                   Acatenango  NaN      -260.0          0.0        0.0
# 7                   Acatenango  NaN      -370.0          0.0        0.0
# 8                   Acatenango  NaN     -2710.0          0.0        0.0
# 9              Acigol-Nevsehir  NaN     -2080.0          0.0        0.0
# 10             Acigol-Nevsehir  NaN     -2370.0          0.0        0.0
# 11             Acigol-Nevsehir  NaN     -3500.0          0.0        0.0
# 12             Acigol-Nevsehir  NaN     -6230.0          0.0        0.0
# 13             Acigol-Nevsehir  NaN     -7810.0          0.0        0.0
# 14                       Adams  2.0       950.0          0.0        0.0
# 15                       Adams  2.0       200.0          0.0        0.0
# 16                       Adams  2.0      -300.0          0.0        0.0
# 17                       Adams  2.0      -400.0          0.0        0.0
# 18                       Adams  2.0      -550.0          0.0        0.0
# 19                       Adams  1.0     -1850.0          0.0        0.0
# 20                       Adams  2.0     -2650.0          0.0        0.0
# 21                       Adams  1.0     -2950.0          0.0        0.0
# 22                       Adams  2.0     -3250.0          0.0        0.0
# 23                       Adams  2.0     -3550.0          0.0        0.0
# 24                       Adams  1.0     -3800.0          0.0        0.0
# 25                       Adams  2.0     -4050.0          0.0        0.0
# 26                       Adams  2.0     -4550.0          0.0        0.0
# 27                       Adams  2.0     -5150.0          0.0        0.0
# 28                       Adams  2.0     -7050.0          0.0        0.0
# 29              Adams Seamount  0.0       -50.0          0.0        0.0
# ...                        ...  ...         ...          ...        ...
# 9810                Zavaritsky  4.0      -850.0          0.0        0.0
# 9811        Zavaritzki Caldera  3.0      1957.0         11.0       12.0
# 9812        Zavaritzki Caldera  1.0      1923.0          0.0        0.0
# 9813                Zavodovski  1.0      2016.0          3.0       30.0
# 9814                Zavodovski  2.0      1819.0         12.0        0.0
# 9815                Zheltovsky  3.0      1923.0          2.0       11.0
# 9816                Zheltovsky  5.0     -3050.0          0.0        0.0
# 9817                Zheltovsky  NaN     -6050.0          0.0        0.0
# 9818                Zheltovsky  5.0     -7050.0          0.0        0.0
# 9819               Zhupanovsky  2.0      2016.0         11.0       20.0
# 9820               Zhupanovsky  3.0      2014.0          6.0        6.0
# 9821               Zhupanovsky  3.0      2013.0         10.0       23.0
# 9822               Zhupanovsky  2.0      1959.0          7.0        2.0
# 9823               Zhupanovsky  2.0      1956.0         12.0       27.0
# 9824               Zhupanovsky  2.0      1940.0          1.0        0.0
# 9825               Zhupanovsky  2.0      1929.0          0.0        0.0
# 9826               Zhupanovsky  2.0      1925.0          0.0        0.0
# 9827               Zhupanovsky  2.0      1882.0          0.0        0.0
# 9828               Zhupanovsky  2.0      1776.0         10.0        0.0
# 9829               Zhupanovsky  NaN      1000.0          0.0        0.0
# 9830               Zhupanovsky  NaN       -50.0          0.0        0.0
# 9831               Zhupanovsky  NaN      -220.0          0.0        0.0
# 9832               Zhupanovsky  NaN     -3050.0          0.0        0.0
# 9833               Zhupanovsky  NaN     -5050.0          0.0        0.0
# 9834  Zitacuaro-Valle de Bravo  0.0     -3050.0          0.0        0.0
# 9835              Zubair Group  2.0      2013.0          9.0       28.0
# 9836              Zubair Group  2.0      2011.0         12.0       18.0
# 9837              Zubair Group  2.0      1824.0          0.0        0.0
# 9838              Zuni-Bandera  0.0     -1170.0          0.0        0.0
# 9839              Zuni-Bandera  NaN     -8710.0          0.0        0.0
#
#       End Year  End Month  End Day          Country_x  \
# 0          NaN        NaN      NaN              Japan
# 1       1972.0       12.0     16.0          Guatemala
# 2       1927.0        5.0     19.0          Guatemala
# 3       1925.0        6.0      7.0          Guatemala
# 4          NaN        NaN      NaN          Guatemala
# 5          NaN        NaN      NaN          Guatemala
# 6          NaN        NaN      NaN          Guatemala
# 7          NaN        NaN      NaN          Guatemala
# 8          NaN        NaN      NaN          Guatemala
# 9          NaN        NaN      NaN             Turkey
# 10         NaN        NaN      NaN             Turkey
# 11         NaN        NaN      NaN             Turkey
# 12         NaN        NaN      NaN             Turkey
# 13         NaN        NaN      NaN             Turkey
# 14         NaN        NaN      NaN      United States
# 15         NaN        NaN      NaN      United States
# 16         NaN        NaN      NaN      United States
# 17         NaN        NaN      NaN      United States
# 18         NaN        NaN      NaN      United States
# 19         NaN        NaN      NaN      United States
# 20         NaN        NaN      NaN      United States
# 21         NaN        NaN      NaN      United States
# 22         NaN        NaN      NaN      United States
# 23         NaN        NaN      NaN      United States
# 24         NaN        NaN      NaN      United States
# 25         NaN        NaN      NaN      United States
# 26         NaN        NaN      NaN      United States
# 27         NaN        NaN      NaN      United States
# 28         NaN        NaN      NaN      United States
# 29         NaN        NaN      NaN  Undersea Features
# ...        ...        ...      ...                ...
# 9810       NaN        NaN      NaN             Russia
# 9811    1957.0       12.0      1.0             Russia
# 9812       NaN        NaN      NaN             Russia
# 9813    2016.0        5.0     16.0     United Kingdom
# 9814       NaN        NaN      NaN     United Kingdom
# 9815    1923.0        4.0      0.0             Russia
# 9816       NaN        NaN      NaN             Russia
# 9817       NaN        NaN      NaN             Russia
# 9818       NaN        NaN      NaN             Russia
# 9819    2016.0       11.0     20.0             Russia
# 9820    2016.0        3.0     24.0             Russia
# 9821    2013.0       10.0     26.0             Russia
# 9822       NaN        NaN      NaN             Russia
# 9823    1957.0        6.0     16.0             Russia
# 9824    1940.0        2.0      0.0             Russia
# 9825       NaN        NaN      NaN             Russia
# 9826       NaN        NaN      NaN             Russia
# 9827       NaN        NaN      NaN             Russia
# 9828       NaN        NaN      NaN             Russia
# 9829       NaN        NaN      NaN             Russia
# 9830       NaN        NaN      NaN             Russia
# 9831       NaN        NaN      NaN             Russia
# 9832       NaN        NaN      NaN             Russia
# 9833       NaN        NaN      NaN             Russia
# 9834       NaN        NaN      NaN             Mexico
# 9835    2013.0       11.0     20.0              Yemen
# 9836    2012.0        1.0     12.0              Yemen
# 9837       NaN        NaN      NaN              Yemen
# 9838       NaN        NaN      NaN      United States
# 9839       NaN        NaN      NaN      United States
#
#                             Region_x  Latitude  Longitude  Elevation_x  \
# 0            Japan, Taiwan, Marianas    34.500    131.600          641
# 1         México and Central America    14.501    -90.876         3976
# 2         México and Central America    14.501    -90.876         3976
# 3         México and Central America    14.501    -90.876         3976
# 4         México and Central America    14.501    -90.876         3976
# 5         México and Central America    14.501    -90.876         3976
# 6         México and Central America    14.501    -90.876         3976
# 7         México and Central America    14.501    -90.876         3976
# 8         México and Central America    14.501    -90.876         3976
# 9     Mediterranean and Western Asia    38.537     34.621         1683
# 10    Mediterranean and Western Asia    38.537     34.621         1683
# 11    Mediterranean and Western Asia    38.537     34.621         1683
# 12    Mediterranean and Western Asia    38.537     34.621         1683
# 13    Mediterranean and Western Asia    38.537     34.621         1683
# 14            Canada and Western USA    46.206   -121.490         3742
# 15            Canada and Western USA    46.206   -121.490         3742
# 16            Canada and Western USA    46.206   -121.490         3742
# 17            Canada and Western USA    46.206   -121.490         3742
# 18            Canada and Western USA    46.206   -121.490         3742
# 19            Canada and Western USA    46.206   -121.490         3742
# 20            Canada and Western USA    46.206   -121.490         3742
# 21            Canada and Western USA    46.206   -121.490         3742
# 22            Canada and Western USA    46.206   -121.490         3742
# 23            Canada and Western USA    46.206   -121.490         3742
# 24            Canada and Western USA    46.206   -121.490         3742
# 25            Canada and Western USA    46.206   -121.490         3742
# 26            Canada and Western USA    46.206   -121.490         3742
# 27            Canada and Western USA    46.206   -121.490         3742
# 28            Canada and Western USA    46.206   -121.490         3742
# 29          Hawaii and Pacific Ocean   -25.370   -129.270          -39
# ...                              ...       ...        ...          ...
# 9810     Kamchatka and Mainland Asia    53.905    158.385         1567
# 9811                   Kuril Islands    46.925    151.950          624
# 9812                   Kuril Islands    46.925    151.950          624
# 9813                      Antarctica   -56.300    -27.570          551
# 9814                      Antarctica   -56.300    -27.570          551
# 9815     Kamchatka and Mainland Asia    51.577    157.328         1926
# 9816     Kamchatka and Mainland Asia    51.577    157.328         1926
# 9817     Kamchatka and Mainland Asia    51.577    157.328         1926
# 9818     Kamchatka and Mainland Asia    51.577    157.328         1926
# 9819     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9820     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9821     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9822     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9823     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9824     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9825     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9826     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9827     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9828     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9829     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9830     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9831     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9832     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9833     Kamchatka and Mainland Asia    53.589    159.150         2899
# 9834      México and Central America    19.400   -100.250         3500
# 9835              Africa and Red Sea    15.050     42.180          191
# 9836              Africa and Red Sea    15.050     42.180          191
# 9837              Africa and Red Sea    15.050     42.180          191
# 9838          Canada and Western USA    34.800   -108.000         2550
# 9839          Canada and Western USA    34.800   -108.000         2550
#
#      Primary Volcano Type_x      Country_y       Region_y  Elevation_y  \
# 0                 Shield(s)          Japan   Honshu-Japan        571.0
# 1         Stratovolcano(es)      Guatemala      Guatemala       3976.0
# 2         Stratovolcano(es)      Guatemala      Guatemala       3976.0
# 3         Stratovolcano(es)      Guatemala      Guatemala       3976.0
# 4         Stratovolcano(es)      Guatemala      Guatemala       3976.0
# 5         Stratovolcano(es)      Guatemala      Guatemala       3976.0
# 6         Stratovolcano(es)      Guatemala      Guatemala       3976.0
# 7         Stratovolcano(es)      Guatemala      Guatemala       3976.0
# 8         Stratovolcano(es)      Guatemala      Guatemala       3976.0
# 9                   Caldera            NaN            NaN          NaN
# 10                  Caldera            NaN            NaN          NaN
# 11                  Caldera            NaN            NaN          NaN
# 12                  Caldera            NaN            NaN          NaN
# 13                  Caldera            NaN            NaN          NaN
# 14            Stratovolcano  United States  US-Washington       3742.0
# 15            Stratovolcano  United States  US-Washington       3742.0
# 16            Stratovolcano  United States  US-Washington       3742.0
# 17            Stratovolcano  United States  US-Washington       3742.0
# 18            Stratovolcano  United States  US-Washington       3742.0
# 19            Stratovolcano  United States  US-Washington       3742.0
# 20            Stratovolcano  United States  US-Washington       3742.0
# 21            Stratovolcano  United States  US-Washington       3742.0
# 22            Stratovolcano  United States  US-Washington       3742.0
# 23            Stratovolcano  United States  US-Washington       3742.0
# 24            Stratovolcano  United States  US-Washington       3742.0
# 25            Stratovolcano  United States  US-Washington       3742.0
# 26            Stratovolcano  United States  US-Washington       3742.0
# 27            Stratovolcano  United States  US-Washington       3742.0
# 28            Stratovolcano  United States  US-Washington       3742.0
# 29                Submarine            NaN            NaN          NaN
# ...                     ...            ...            ...          ...
# 9810    Pyroclastic cone(s)         Russia      Kamchatka       1567.0
# 9811                Caldera         Russia       Kuril Is        624.0
# 9812                Caldera         Russia       Kuril Is        624.0
# 9813          Stratovolcano     Antarctica     Antarctica        551.0
# 9814          Stratovolcano     Antarctica     Antarctica        551.0
# 9815          Stratovolcano            NaN            NaN          NaN
# 9816          Stratovolcano            NaN            NaN          NaN
# 9817          Stratovolcano            NaN            NaN          NaN
# 9818          Stratovolcano            NaN            NaN          NaN
# 9819               Compound            NaN            NaN          NaN
# 9820               Compound            NaN            NaN          NaN
# 9821               Compound            NaN            NaN          NaN
# 9822               Compound            NaN            NaN          NaN
# 9823               Compound            NaN            NaN          NaN
# 9824               Compound            NaN            NaN          NaN
# 9825               Compound            NaN            NaN          NaN
# 9826               Compound            NaN            NaN          NaN
# 9827               Compound            NaN            NaN          NaN
# 9828               Compound            NaN            NaN          NaN
# 9829               Compound            NaN            NaN          NaN
# 9830               Compound            NaN            NaN          NaN
# 9831               Compound            NaN            NaN          NaN
# 9832               Compound            NaN            NaN          NaN
# 9833               Compound            NaN            NaN          NaN
# 9834                Caldera            NaN            NaN          NaN
# 9835                 Shield            NaN            NaN          NaN
# 9836                 Shield            NaN            NaN          NaN
# 9837                 Shield            NaN            NaN          NaN
# 9838         Volcanic field  United States  US-New Mexico       2550.0
# 9839         Volcanic field  United States  US-New Mexico       2550.0
#
#      Primary Volcano Type_y            Status
# 0            Shield volcano          Holocene
# 1             Stratovolcano        Historical
# 2             Stratovolcano        Historical
# 3             Stratovolcano        Historical
# 4             Stratovolcano        Historical
# 5             Stratovolcano        Historical
# 6             Stratovolcano        Historical
# 7             Stratovolcano        Historical
# 8             Stratovolcano        Historical
# 9                       NaN               NaN
# 10                      NaN               NaN
# 11                      NaN               NaN
# 12                      NaN               NaN
# 13                      NaN               NaN
# 14            Stratovolcano  Tephrochronology
# 15            Stratovolcano  Tephrochronology
# 16            Stratovolcano  Tephrochronology
# 17            Stratovolcano  Tephrochronology
# 18            Stratovolcano  Tephrochronology
# 19            Stratovolcano  Tephrochronology
# 20            Stratovolcano  Tephrochronology
# 21            Stratovolcano  Tephrochronology
# 22            Stratovolcano  Tephrochronology
# 23            Stratovolcano  Tephrochronology
# 24            Stratovolcano  Tephrochronology
# 25            Stratovolcano  Tephrochronology
# 26            Stratovolcano  Tephrochronology
# 27            Stratovolcano  Tephrochronology
# 28            Stratovolcano  Tephrochronology
# 29                      NaN               NaN
# ...                     ...               ...
# 9810           Cinder cones       Radiocarbon
# 9811                Caldera        Historical
# 9812                Caldera        Historical
# 9813          Stratovolcano        Historical
# 9814          Stratovolcano        Historical
# 9815                    NaN               NaN
# 9816                    NaN               NaN
# 9817                    NaN               NaN
# 9818                    NaN               NaN
# 9819                    NaN               NaN
# 9820                    NaN               NaN
# 9821                    NaN               NaN
# 9822                    NaN               NaN
# 9823                    NaN               NaN
# 9824                    NaN               NaN
# 9825                    NaN               NaN
# 9826                    NaN               NaN
# 9827                    NaN               NaN
# 9828                    NaN               NaN
# 9829                    NaN               NaN
# 9830                    NaN               NaN
# 9831                    NaN               NaN
# 9832                    NaN               NaN
# 9833                    NaN               NaN
# 9834                    NaN               NaN
# 9835                    NaN               NaN
# 9836                    NaN               NaN
# 9837                    NaN               NaN
# 9838         Volcanic field      Anthropology
# 9839         Volcanic field      Anthropology
#
# [9840 rows x 19 columns]

# %%
df_erupt_merge2.to_csv('data_check/EruptionData1_chk.csv')

# %%
df_erupt_merge3 = df_erupt_merge2.where((pd.notnull(df_erupt_merge2)), None)

for index, row in df_erupt_merge3.iterrows():
    if row['Country_x'] is None:
        print('.', end='')
        row['Country_x'] = row['Country_y']
        row['Primary Volcano Type_x'] = row['Primary Volcano Type_y']
        row['Region_x'] = row['Region_y']
        row['Elevation_x'] = row['Elevation_y']
    else:
        print('-', end = '')
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Handling Start Date Tip
# https://www.ngdc.noaa.gov/nndc/DescribeField.jsp?dataset=102557&s=77&field_name=HAZ.VOLCANO_EVENT.DAY
#
# Day:
# Valid values: 1-31 (where months apply)
# The Date and Time are given in Universal Coordinated Time (also known as Greenwich Mean Time). The local date may be one day different.

# %%
df_erupt_merge4 = df_erupt_merge3.drop([
    'Country_y','Region_y',
    'Elevation_y',
    'Primary Volcano Type_y'], axis=1).rename(columns = {
    'Country_x' : 'Country',
    'Region_x' : 'Region',
    'Elevation_x' : 'Elevation',
    'Primary Volcano Type_x' : 'Primary Volcano Type'})
# .fillna({
#     'VEI':0,'Start Month':0,'Start Day':0,
#     'End Year':0,'End Month':0,'End Day':0})

df_erupt_merge4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9840 entries, 0 to 9839
# Data columns (total 15 columns):
# Volcano Name            9840 non-null object
# VEI                     7563 non-null object
# Start Year              9839 non-null object
# Start Month             9659 non-null object
# Start Day               9658 non-null object
# End Year                3942 non-null object
# End Month               3940 non-null object
# End Day                 3939 non-null object
# Country                 9840 non-null object
# Region                  9840 non-null object
# Latitude                9840 non-null object
# Longitude               9840 non-null object
# Elevation               9840 non-null int64
# Primary Volcano Type    9763 non-null object
# Status                  2691 non-null object
# dtypes: int64(1), object(14)
# memory usage: 1.2+ MB

# %%
# remove row with no start erruption date

for index, row in df_erupt_merge4.iterrows():
    if row['Start Year']is None:
        df_erupt_merge4.drop(index, inplace=True)
    else:
        print('.',end='')
df_erupt_merge4.info()
# Out:
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# ...............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................<class 'pandas.core.frame.DataFrame'>
# Int64Index: 9839 entries, 0 to 9839
# Data columns (total 15 columns):
# Volcano Name            9839 non-null object
# VEI                     7563 non-null object
# Start Year              9839 non-null object
# Start Month             9659 non-null object
# Start Day               9658 non-null object
# End Year                3942 non-null object
# End Month               3940 non-null object
# End Day                 3939 non-null object
# Country                 9839 non-null object
# Region                  9839 non-null object
# Latitude                9839 non-null object
# Longitude               9839 non-null object
# Elevation               9839 non-null int64
# Primary Volcano Type    9762 non-null object
# Status                  2690 non-null object
# dtypes: int64(1), object(14)
# memory usage: 1.2+ MB

# %%
df_erupt_merge4.to_csv('data_check/EruptionData2_chk.csv', index=False)

# %%
df3_vol_gvp =  df2_vol_gvp[['Volcano Name','Country','Region','Latitude','Longitude','Elevation','Primary Volcano Type']].dropna(subset = ['Country']).reset_index(drop=True)
df3_vol_gvp.info()
df3_vol_gvp
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1444 entries, 0 to 1443
# Data columns (total 7 columns):
# Volcano Name            1444 non-null object
# Country                 1444 non-null object
# Region                  1444 non-null object
# Latitude                1444 non-null float64
# Longitude               1444 non-null float64
# Elevation               1444 non-null int64
# Primary Volcano Type    1443 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 79.0+ KB
#                   Volcano Name            Country  \
# 0                          Abu              Japan
# 1                   Acamarachi              Chile
# 2                   Acatenango          Guatemala
# 3              Acigol-Nevsehir             Turkey
# 4                        Adams      United States
# 5               Adams Seamount  Undersea Features
# 6                  Adatarayama              Japan
# 7                         Adwa           Ethiopia
# 8                       Afdera           Ethiopia
# 9                      Agrigan      United States
# 10                        Agua          Guatemala
# 11                 Agua de Pau           Portugal
# 12                    Aguilera              Chile
# 13                       Agung          Indonesia
# 14                        Ahyi      United States
# 15                        Aira              Japan
# 16               Akademia Nauk             Russia
# 17                    Akagisan              Japan
# 18                        Akan              Japan
# 19                Akandanayama              Japan
# 20                     Akhtang             Russia
# 21            Akita-Komagatake              Japan
# 22              Akita-Yakeyama              Japan
# 23                 Akusekijima              Japan
# 24                      Akutan      United States
# 25                       Alaid             Russia
# 26                    Alamagan      United States
# 27                      Alayta           Ethiopia
# 28                      Alcedo            Ecuador
# 29                    Ale Bagu           Ethiopia
# ...                        ...                ...
# 1414                  Yanteles              Chile
# 1415                Yar, Jabal       Saudi Arabia
# 1416                     Yasur            Vanuatu
# 1417                      Yate              Chile
# 1418                  Yavinsky             Russia
# 1419               Yellowstone      United States
# 1420               Yojoa, Lake           Honduras
# 1421              Yokoate-jima              Japan
# 1422                  Yokodake              Japan
# 1423     Yonemaru-Sumiyoshiike              Japan
# 1424                  Yoteizan              Japan
# 1425              Young Island         Antarctica
# 1426                  Yucamane               Peru
# 1428                          Alaska    52.643   -170.629        550
# 1429      México and Central America    13.330    -87.630        640
# 1430         Japan, Taiwan, Marianas    38.144    140.440       1841
# 1431     Kamchatka and Mainland Asia    56.880    159.950       1349
# 1432      México and Central America    11.730    -85.820        629
# 1433     Kamchatka and Mainland Asia    53.905    158.385       1567
# 1434                   Kuril Islands    46.925    151.950        624
# 1435                      Antarctica   -56.300    -27.570        551
# 1436         Japan, Taiwan, Marianas    16.880    145.850          0
# 1437     Kamchatka and Mainland Asia    51.577    157.328       1926
# 1438     Kamchatka and Mainland Asia    53.589    159.150       2899
# 1439     Kamchatka and Mainland Asia    55.862    160.603       3057
# 1440      México and Central America    19.400   -100.250       3500
# 1441              Africa and Red Sea    15.050     42.180        191
# 1442              Africa and Red Sea    14.020     42.750        624
# 1443          Canada and Western USA    34.800   -108.000       2550
#
#      Primary Volcano Type
# 0               Shield(s)
# 1           Stratovolcano
# 2       Stratovolcano(es)
# 3                 Caldera
# 4           Stratovolcano
# 5               Submarine
# 6       Stratovolcano(es)
# 7           Stratovolcano
# 8           Stratovolcano
# 9           Stratovolcano
# 10          Stratovolcano
# 11          Stratovolcano
# 12          Stratovolcano
# 13          Stratovolcano
# 14              Submarine
# 15                Caldera
# 16      Stratovolcano(es)
# 17          Stratovolcano
# 18                Caldera
# 19          Stratovolcano
# 20                 Shield
# 21      Stratovolcano(es)
# 22          Stratovolcano
# 23      Stratovolcano(es)
# 24          Stratovolcano
# 25          Stratovolcano
# 26          Stratovolcano
# 27                 Shield
# 28                 Shield
# 29          Stratovolcano
# ...                   ...
# 1414    Stratovolcano(es)
# 1415       Volcanic field
# 1416        Stratovolcano
# 1417        Stratovolcano
# 1418        Stratovolcano
# 1419           Caldera(s)
# 1420       Volcanic field
# 1421    Stratovolcano(es)
# 1422    Stratovolcano(es)
# 1423              Maar(s)
# 1424        Stratovolcano
# 1425        Stratovolcano
# 1426    Stratovolcano(es)
# 1427         Lava dome(s)
# 1428               Shield
# 1429        Stratovolcano
# 1430              Complex
# 1431            Shield(s)
# 1432               Shield
# 1433  Pyroclastic cone(s)
# 1434              Caldera
# 1435        Stratovolcano
# 1436        Stratovolcano
# 1437        Stratovolcano
# 1438             Compound
# 1439    Stratovolcano(es)
# 1440              Caldera
# 1441               Shield
# 1442               Shield
# 1443       Volcanic field
#
# [1444 rows x 7 columns]

# %% [markdown]
# ## Merge by Name & Latitude (Floating Point Issue Resolved)

# %%
df_erupt_merge5 = pd.merge(df_erupt_merge4, df3_vol_gvp, how='left', on=['Volcano Name','Latitude'], left_on=None, right_on=None,
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False)

df_erupt_merge5.info()
df_erupt_merge5
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9839 entries, 0 to 9838
# Data columns (total 20 columns):
# Volcano Name              9839 non-null object
# VEI                       7563 non-null object
# Start Year                9839 non-null object
# Start Month               9659 non-null object
# Start Day                 9658 non-null object
# End Year                  3942 non-null object
# End Month                 3940 non-null object
# End Day                   3939 non-null object
# Country_x                 9839 non-null object
# Region_x                  9839 non-null object
# Latitude                  9839 non-null object
# Longitude_x               9839 non-null object
# Elevation_x               9839 non-null int64
# Primary Volcano Type_x    9762 non-null object
# Status                    2690 non-null object
# Country_y                 9839 non-null object
# Region_y                  9839 non-null object
# Longitude_y               9839 non-null float64
# Elevation_y               9839 non-null int64
# Primary Volcano Type_y    9762 non-null object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.6+ MB
#                   Volcano Name   VEI Start Year Start Month Start Day  \
# 0                          Abu  None      -6850           0         0
# 1                   Acatenango     1       1972          11        12
# 2                   Acatenango     2       1926           8         0
# 3                   Acatenango     3       1924          12        18
# 4                   Acatenango  None       1450           0         0
# 5                   Acatenango  None         90           0         0
# 6                   Acatenango  None       -260           0         0
# 7                   Acatenango  None       -370           0         0
# 8                   Acatenango  None      -2710           0         0
# 9              Acigol-Nevsehir  None      -2080           0         0
# 10             Acigol-Nevsehir  None      -2370           0         0
# 11             Acigol-Nevsehir  None      -3500           0         0
# 12             Acigol-Nevsehir  None      -6230           0         0
# 13             Acigol-Nevsehir  None      -7810           0         0
# 14                       Adams     2        950           0         0
# 15                       Adams     2        200           0         0
# 16                       Adams     2       -300           0         0
# 17                       Adams     2       -400           0         0
# 18                       Adams     2       -550           0         0
# 19                       Adams     1      -1850           0         0
# 20                       Adams     2      -2650           0         0
# 21                       Adams     1      -2950           0         0
# 22                       Adams     2      -3250           0         0
# 23                       Adams     2      -3550           0         0
# 24                       Adams     1      -3800           0         0
# 25                       Adams     2      -4050           0         0
# 26                       Adams     2      -4550           0         0
# 27                       Adams     2      -5150           0         0
# 28                       Adams     2      -7050           0         0
# 29              Adams Seamount     0        -50           0         0
# ...                        ...   ...        ...         ...       ...
# 9809                Zavaritsky     4       -850           0         0
# 9810        Zavaritzki Caldera     3       1957          11        12
# 9811        Zavaritzki Caldera     1       1923           0         0
# 9812                Zavodovski     1       2016           3        30
# 9813                Zavodovski     2       1819          12         0
# 9814                Zheltovsky     3       1923           2        11
# 9815                Zheltovsky     5      -3050           0         0
# 9816                Zheltovsky  None      -6050           0         0
# 9817                Zheltovsky     5      -7050           0         0
# 9818               Zhupanovsky     2       2016          11        20
# 9819               Zhupanovsky     3       2014           6         6
# 9820               Zhupanovsky     3       2013          10        23
# 9821               Zhupanovsky     2       1959           7         2
# 9822               Zhupanovsky     2       1956          12        27
# 9823               Zhupanovsky     2       1940           1         0
# 9824               Zhupanovsky     2       1929           0         0
# 9825               Zhupanovsky     2       1925           0         0
# 9826               Zhupanovsky     2       1882           0         0
# 9827               Zhupanovsky     2       1776          10         0
# 9828               Zhupanovsky  None       1000           0         0
# 9829               Zhupanovsky  None        -50           0         0
# 9830               Zhupanovsky  None       -220           0         0
# 9831               Zhupanovsky  None      -3050           0         0
# 9832               Zhupanovsky  None      -5050           0         0
# 9833  Zitacuaro-Valle de Bravo     0      -3050           0         0
# 9834              Zubair Group     2       2013           9        28
# 9835              Zubair Group     2       2011          12        18
# 9836              Zubair Group     2       1824           0         0
# 9837              Zuni-Bandera     0      -1170           0         0
# 9838              Zuni-Bandera  None      -8710           0         0
#
#      End Year End Month End Day          Country_x  \
# 0        None      None    None              Japan
# 1        1972        12      16          Guatemala
# 2        1927         5      19          Guatemala
# 26            Canada and Western USA   46.206     -121.49         3742
# 27            Canada and Western USA   46.206     -121.49         3742
# 28            Canada and Western USA   46.206     -121.49         3742
# 29          Hawaii and Pacific Ocean   -25.37     -129.27          -39
# ...                              ...      ...         ...          ...
# 9809     Kamchatka and Mainland Asia   53.905     158.385         1567
# 9810                   Kuril Islands   46.925      151.95          624
# 9811                   Kuril Islands   46.925      151.95          624
# 9812                      Antarctica    -56.3      -27.57          551
# 9813                      Antarctica    -56.3      -27.57          551
# 9814     Kamchatka and Mainland Asia   51.577     157.328         1926
# 9815     Kamchatka and Mainland Asia   51.577     157.328         1926
# 9816     Kamchatka and Mainland Asia   51.577     157.328         1926
# 9817     Kamchatka and Mainland Asia   51.577     157.328         1926
# 9818     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9819     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9820     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9821     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9822     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9823     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9824     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9825     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9826     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9827     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9828     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9829     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9830     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9831     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9832     Kamchatka and Mainland Asia   53.589      159.15         2899
# 9833      México and Central America     19.4     -100.25         3500
# 9834              Africa and Red Sea    15.05       42.18          191
# 9835              Africa and Red Sea    15.05       42.18          191
# 9836              Africa and Red Sea    15.05       42.18          191
# 9837          Canada and Western USA     34.8        -108         2550
# 9838          Canada and Western USA     34.8        -108         2550
#
#      Primary Volcano Type_x            Status          Country_y  \
# 0                 Shield(s)          Holocene              Japan
# 1         Stratovolcano(es)        Historical          Guatemala
# 2         Stratovolcano(es)        Historical          Guatemala
# 3         Stratovolcano(es)        Historical          Guatemala
# 4         Stratovolcano(es)        Historical          Guatemala
# 5         Stratovolcano(es)        Historical          Guatemala
# 6         Stratovolcano(es)        Historical          Guatemala
# 7         Stratovolcano(es)        Historical          Guatemala
# 8         Stratovolcano(es)        Historical          Guatemala
# 9                   Caldera              None             Turkey
# 10                  Caldera              None             Turkey
# 11                  Caldera              None             Turkey
# 12                  Caldera              None             Turkey
# 13                  Caldera              None             Turkey
# 14            Stratovolcano  Tephrochronology      United States
# 15            Stratovolcano  Tephrochronology      United States
# 16            Stratovolcano  Tephrochronology      United States
# 17            Stratovolcano  Tephrochronology      United States
# 18            Stratovolcano  Tephrochronology      United States
# 19            Stratovolcano  Tephrochronology      United States
# 20            Stratovolcano  Tephrochronology      United States
# 21            Stratovolcano  Tephrochronology      United States
# 22            Stratovolcano  Tephrochronology      United States
# 23            Stratovolcano  Tephrochronology      United States
# 24            Stratovolcano  Tephrochronology      United States
# 25            Stratovolcano  Tephrochronology      United States
# 26            Stratovolcano  Tephrochronology      United States
# 27            Stratovolcano  Tephrochronology      United States
# 28            Stratovolcano  Tephrochronology      United States
# 29                Submarine              None  Undersea Features
# ...                     ...               ...                ...
# 9809    Pyroclastic cone(s)       Radiocarbon             Russia
# 9810                Caldera        Historical             Russia
# 9811                Caldera        Historical             Russia
# 9812          Stratovolcano        Historical     United Kingdom
# 9813          Stratovolcano        Historical     United Kingdom
# 9814          Stratovolcano              None             Russia
# 9815          Stratovolcano              None             Russia
# 9816          Stratovolcano              None             Russia
# 9817          Stratovolcano              None             Russia
# 9818               Compound              None             Russia
# 9819               Compound              None             Russia
# 9831     Kamchatka and Mainland Asia      159.150         2899
# 9832     Kamchatka and Mainland Asia      159.150         2899
# 9833      México and Central America     -100.250         3500
# 9834              Africa and Red Sea       42.180          191
# 9835              Africa and Red Sea       42.180          191
# 9836              Africa and Red Sea       42.180          191
# 9837          Canada and Western USA     -108.000         2550
# 9838          Canada and Western USA     -108.000         2550
#
#      Primary Volcano Type_y
# 0                 Shield(s)
# 1         Stratovolcano(es)
# 2         Stratovolcano(es)
# 3         Stratovolcano(es)
# 4         Stratovolcano(es)
# 5         Stratovolcano(es)
# 6         Stratovolcano(es)
# 7         Stratovolcano(es)
# 8         Stratovolcano(es)
# 9                   Caldera
# 10                  Caldera
# 11                  Caldera
# 12                  Caldera
# 13                  Caldera
# 14            Stratovolcano
# 15            Stratovolcano
# 16            Stratovolcano
# 17            Stratovolcano
# 18            Stratovolcano
# 19            Stratovolcano
# 20            Stratovolcano
# 21            Stratovolcano
# 22            Stratovolcano
# 23            Stratovolcano
# 24            Stratovolcano
# 25            Stratovolcano
# 26            Stratovolcano
# 27            Stratovolcano
# 28            Stratovolcano
# 29                Submarine
# ...                     ...
# 9809    Pyroclastic cone(s)
# 9810                Caldera
# 9811                Caldera
# 9812          Stratovolcano
# 9813          Stratovolcano
# 9814          Stratovolcano
# 9815          Stratovolcano
# 9816          Stratovolcano
# 9817          Stratovolcano
# 9818               Compound
# 9819               Compound
# 9820               Compound
# 9821               Compound
# 9822               Compound
# 9823               Compound
# 9824               Compound
# 9825               Compound
# 9826               Compound
# 9827               Compound
# 9828               Compound
# 9829               Compound
# 9830               Compound
# 9831               Compound
# 9832               Compound
# 9833                Caldera
# 9834                 Shield
# 9835                 Shield
# 9836                 Shield
# 9837         Volcanic field
# 9838         Volcanic field
#
# [9839 rows x 20 columns]

# %%
df_erupt_merge5.to_csv('data_check/EruptionData3_chk.csv')

# %%
df_erupt_merge6 = df_erupt_merge5.where((pd.notnull(df_erupt_merge5)), None)

for index, row in df_erupt_merge6.iterrows():
    if row['Country_x'] is None:
        print('.', end='')
        row['Country_x'] = row['Country_y']
        row['Region_x'] = row['Region_y']
        row['Elevation_x'] = row['Elevation_y']
        row['Primary Volcano Type_x'] = row['Primary Volcano Type_y']
    else:
        print('-', end = '')

df_erupt_merge7 = df_erupt_merge6.drop([
    'Longitude_y','Country_y',
    'Region_y','Elevation_y',
    'Primary Volcano Type_y'], axis=1).rename(columns = {
    'Country_x' : 'Country',
    'Region_x' : 'Region',
    'Longitude_x' : 'Longitude',
    'Elevation_x' : 'Elevation',
    'Primary Volcano Type_x' : 'Primary Volcano Type'})
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df_erupt_merge7.to_csv('data_check/EruptionData4_chk.csv')

# %% [markdown]
# ## Re-merge by Lat/Long

# %%
df_erupt_merge8 = pd.merge(df_erupt_merge7, df3_vol_gvp, how='left', on=['Latitude', 'Longitude'], left_on=None, right_on=None,
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False)

df_erupt_merge8.info()
df_erupt_merge8
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9839 entries, 0 to 9838
# Data columns (total 20 columns):
# Volcano Name_x            9839 non-null object
# VEI                       7563 non-null object
# Start Year                9839 non-null object
# Start Month               9659 non-null object
# Start Day                 9658 non-null object
# End Year                  3942 non-null object
# End Month                 3940 non-null object
# End Day                   3939 non-null object
# Country_x                 9839 non-null object
# Region_x                  9839 non-null object
# Latitude                  9839 non-null object
# Longitude                 9839 non-null object
# Elevation_x               9839 non-null int64
# Primary Volcano Type_x    9762 non-null object
# Status                    2690 non-null object
# Volcano Name_y            9839 non-null object
# Country_y                 9839 non-null object
# Region_y                  9839 non-null object
# Elevation_y               9839 non-null int64
# Primary Volcano Type_y    9762 non-null object
# dtypes: int64(2), object(18)
# memory usage: 1.6+ MB
#                  Volcano Name_x   VEI Start Year Start Month Start Day  \
# 0                        Erebus     2       1972          12        16
# 1                        Erebus     1       1972           1         3
# 2                        Erebus     0       1963          11        16
# 3                        Erebus     2       1955           7         2
# 4                        Erebus     2       1947           2         0
# 5                        Erebus     2       1915           8         0
# 6                        Erebus     2       1915           3        22
# 7                        Erebus     2       1912          12        12
# 8                        Erebus     2       1911          10         0
# 9                        Erebus     2       1911           4         0
# 10                       Erebus     2       1908           3         0
# 11                       Erebus     0       1903           1         1
# 12                       Erebus     1       1841           1        28
# 13                       Erebus     0        950           0         0
# 14                       Erebus     0      -2050           0         0
# 15                       Erebus     0      -2950           0         0
# 16                       Erebus     0      -4050           0         0
# 17                       Erebus     0      -4550           0         0
# 18                       Erebus     0      -7050           0         0
# 19                       Erebus     0      -8050           0         0
# 20                       Takahe  None      -5550           0         0
# 21                       Takahe  None      -6250           0         0
# 22                       Takahe  None      -7050           0         0
# 23                       Berlin     0      -8350           0         0
# 24                    Melbourne  None       1892           0         0
# 25             Hudson Mountains     4       -210           0         0
# 26                Pleiades, The  None      -1050           0         0
# 27                Buckle Island     2       1899           1        12
# 28                Buckle Island     2       1839           2         9
# 29             Deception Island     3       1970           8        12
# ...                         ...   ...        ...         ...       ...
# 9809                     Krafla     0        250           0         0
# 9810                     Krafla     2        -50           0         0
# 9811                     Krafla     2       -300           0         0
# 9812                     Krafla     0       -500           0         0
# 9813                     Krafla     4       -650           0         0
# 9814                     Krafla     0      -3050           0         0
# 9815                     Krafla     0      -4050           0         0
# 9816                     Krafla     0      -5750           0         0
# 9817                     Krafla     0      -6150           0         0
# 9818                     Krafla  None      -6500           0         0
# 9819                     Krafla     2      -6800           0         0
# 9820                     Krafla     2      -6850           0         0
# 9821                     Krafla     0      -6950           0         0
# 9822                     Krafla     0      -7400           0         0
# 9823                     Krafla  None      -7850           0         0
# 9824                     Krafla     0      -8500           0         0
# 9825              Theistareykir     0       -900           0         0
# 9826              Theistareykir     0      -6800           0         0
# 9827              Theistareykir     0      -9500           0         0
# 9828      Tjornes Fracture Zone  None       1867          12         0
# 9829           Kolbeinsey Ridge  None       1755           9        18
# 9830           Kolbeinsey Ridge     2       1372           0         0
# 9831                  Jan Mayen     0       1985           1         6
# 9832                  Jan Mayen     1       1973           1        15
# 9833                  Jan Mayen     3       1970           9        18
# 9834                  Jan Mayen  None       1851           0         0
# 9835                  Jan Mayen     3       1818           4         0
# 9836                  Jan Mayen     3       1732           5        17
# 9835     None      None    None             Norway  Iceland and Arctic Ocean
# 9836     1732         5      18             Norway  Iceland and Arctic Ocean
# 9837     None      None    None             Norway  Iceland and Arctic Ocean
# 9838     1999         4      15  Undersea Features  Iceland and Arctic Ocean
#
#      Latitude Longitude  Elevation_x Primary Volcano Type_x            Status  \
# 0      -77.53    167.17         3794          Stratovolcano        Historical
# 1      -77.53    167.17         3794          Stratovolcano        Historical
# 2      -77.53    167.17         3794          Stratovolcano        Historical
# 3      -77.53    167.17         3794          Stratovolcano        Historical
# 4      -77.53    167.17         3794          Stratovolcano        Historical
# 5      -77.53    167.17         3794          Stratovolcano        Historical
# 6      -77.53    167.17         3794          Stratovolcano        Historical
# 7      -77.53    167.17         3794          Stratovolcano        Historical
# 8      -77.53    167.17         3794          Stratovolcano        Historical
# 9      -77.53    167.17         3794          Stratovolcano        Historical
# 10     -77.53    167.17         3794          Stratovolcano        Historical
# 11     -77.53    167.17         3794          Stratovolcano        Historical
# 12     -77.53    167.17         3794          Stratovolcano        Historical
# 13     -77.53    167.17         3794          Stratovolcano        Historical
# 14     -77.53    167.17         3794          Stratovolcano        Historical
# 15     -77.53    167.17         3794          Stratovolcano        Historical
# 16     -77.53    167.17         3794          Stratovolcano        Historical
# 17     -77.53    167.17         3794          Stratovolcano        Historical
# 18     -77.53    167.17         3794          Stratovolcano        Historical
# 19     -77.53    167.17         3794          Stratovolcano        Historical
# 20     -76.28   -112.08         3460                 Shield          Ice Core
# 21     -76.28   -112.08         3460                 Shield          Ice Core
# 22     -76.28   -112.08         3460                 Shield          Ice Core
# 23     -76.05      -136         3478              Shield(s)         Fumarolic
# 24     -74.35     164.7         2732          Stratovolcano  Tephrochronology
# 25     -74.33    -99.42          749      Stratovolcano(es)         Uncertain
# 26     -72.67     165.5         3040          Stratovolcano              K-Ar
# 27     -66.78    163.25         1239          Stratovolcano              None
# 28     -66.78    163.25         1239          Stratovolcano              None
# 29    -63.001   -60.652          602                Caldera              None
# ...       ...       ...          ...                    ...               ...
# 9809   65.715   -16.728          800                Caldera              None
# 9810   65.715   -16.728          800                Caldera              None
# 9811   65.715   -16.728          800                Caldera              None
# 9812   65.715   -16.728          800                Caldera              None
# 9813   65.715   -16.728          800                Caldera              None
# 9814   65.715   -16.728          800                Caldera              None
# 9815   65.715   -16.728          800                Caldera              None
# 9816   65.715   -16.728          800                Caldera              None
# 9817   65.715   -16.728          800                Caldera              None
# 9818   65.715   -16.728          800                Caldera              None
# 9819   65.715   -16.728          800                Caldera              None
# 9820   65.715   -16.728          800                Caldera              None
# 9821   65.715   -16.728          800                Caldera              None
# 9822   65.715   -16.728          800                Caldera              None
# 9823   65.715   -16.728          800                Caldera              None
# 9824   65.715   -16.728          800                Caldera              None
# 9825   65.833   -17.166          540                 Shield              None
# 9826   65.833   -17.166          540                 Shield              None
# 9827   65.833   -17.166          540                 Shield              None
# 9828   66.309   -17.118          -75              Submarine              None
# 9829    66.67     -18.5            5              Submarine        Historical
# 9830    66.67     -18.5            5              Submarine        Historical
  Jan Mayen             Norway  Iceland and Arctic Ocean
# 9832                  Jan Mayen             Norway  Iceland and Arctic Ocean
# 9833                  Jan Mayen             Norway  Iceland and Arctic Ocean
# 9834                  Jan Mayen             Norway  Iceland and Arctic Ocean
# 9835                  Jan Mayen             Norway  Iceland and Arctic Ocean
# 9836                  Jan Mayen             Norway  Iceland and Arctic Ocean
# 9837                  Jan Mayen             Norway  Iceland and Arctic Ocean
# 9838  East Gakkel Ridge at 85°E  Undersea Features  Iceland and Arctic Ocean
#
#       Elevation_y Primary Volcano Type_y
# 0            3794          Stratovolcano
# 1            3794          Stratovolcano
# 2            3794          Stratovolcano
# 3            3794          Stratovolcano
# 4            3794          Stratovolcano
# 5            3794          Stratovolcano
# 6            3794          Stratovolcano
# 7            3794          Stratovolcano
# 8            3794          Stratovolcano
# 9            3794          Stratovolcano
# 10           3794          Stratovolcano
# 11           3794          Stratovolcano
# 12           3794          Stratovolcano
# 13           3794          Stratovolcano
# 14           3794          Stratovolcano
# 15           3794          Stratovolcano
# 16           3794          Stratovolcano
# 17           3794          Stratovolcano
# 18           3794          Stratovolcano
# 19           3794          Stratovolcano
# 20           3460                 Shield
# 21           3460                 Shield
# 22           3460                 Shield
# 23           3478              Shield(s)
# 24           2732          Stratovolcano
# 25            749      Stratovolcano(es)
# 26           3040          Stratovolcano
# 27           1239          Stratovolcano
# 28           1239          Stratovolcano
# 29            602                Caldera
# ...           ...                    ...
# 9809          800                Caldera
# 9810          800                Caldera
# 9811          800                Caldera
# 9812          800                Caldera
# 9813          800                Caldera
# 9814          800                Caldera
# 9815          800                Caldera
# 9816          800                Caldera
# 9817          800                Caldera
# 9818          800                Caldera
# 9819          800                Caldera
# 9820          800                Caldera
# 9821          800                Caldera
# 9822          800                Caldera
# 9823          800                Caldera
# 9824          800                Caldera
# 9825          540                 Shield
# 9826          540                 Shield
# 9827          540                 Shield
# 9828          -75              Submarine
# 9829            5              Submarine
# 9830            5              Submarine
# 9831         2085          Stratovolcano
# 9832         2085          Stratovolcano
# 9833         2085          Stratovolcano
# 9834         2085          Stratovolcano
# 9835         2085          Stratovolcano
# 9836         2085          Stratovolcano
# 9837         2085          Stratovolcano
# 9838        -3800              Submarine
#
# [9839 rows x 20 columns]

# %%
df_erupt_merge8.to_csv('data_check/EruptionData5_chk.csv')

# %%
df_erupt_merge9 = df_erupt_merge8.where((pd.notnull(df_erupt_merge8)), None)

for index, row in df_erupt_merge9.iterrows():
    if row['Country_x'] is None:
        print('.', end='')
        row['Country_x'] = row['Country_y']
        row['Region_x'] = row['Region_y']
        row['Elevation_x'] = row['Elevation_y']
        row['Primary Volcano Type_x'] = row['Primary Volcano Type_y']
    else:
        print('-', end = '')

df_erupt_final = df_erupt_merge9.drop([
    'Volcano Name_y',
    'Country_y','Region_y','Elevation_y',
    'Primary Volcano Type_y'], axis=1).rename(columns = {
    'Volcano Name_x':'Volcano Name',
    'Country_x' : 'Country',
    'Region_x' : 'Region',
    'Elevation_x' : 'Elevation',
    'Primary Volcano Type_x' : 'Primary Volcano Type'})
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df_erupt_final.to_csv('finalized_data/clean_eruptions.csv', index=True, encoding = 'utf-8')

# %%
df_erupt_final.to_excel('finalized_data/clean_eruptions.xlsx', index=True)
